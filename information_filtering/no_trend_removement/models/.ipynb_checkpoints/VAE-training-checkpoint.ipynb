# %% [markdown]
# # Autoencoder
# This notebook makes use of the **Autoencoder**, which is used to reduce the dimensionality of our dataset in a non-linear way. Furthermore, we then apply **k-means Clustering** as in our last notebook in our new created **Latent Space** in lower dimension. We do so, to get rid of less important variables and achieve a better Clustering.

# %%
# !pip install -q -r ../../requirements.txt &> /dev/null

# %%
from ipywidgets import FloatSlider
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from ipywidgets import interact, IntSlider
from sklearn.decomposition import PCA
import numpy as np
import pandas as pd
import matplotlib.dates as mdates

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchinfo import summary
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from torch.utils.data import DataLoader, TensorDataset

import sys
sys.path.append('../..')
import helper_functions     # Own file.
import importlib
importlib.reload(helper_functions)
# Out:
# <module 'helper_functions' from '/home/jovyan/spatiotemporal-mining-medsea/information_filtering/no_trend_removement/models/../../helper_functions.py'>

# %% [markdown]
# ## Data Loading & Preprocessing

# %%
ds = xr.open_dataset("/home/jovyan/spatiotemporal-mining-medsea/data/medsea.nc")
print(ds.nbytes / 1e6, "MB")

z_temp = helper_functions.preprocessing(ds, ["thetao", "so"], [50, 300, 1000], "location", False, -1)
print(z_temp.shape)
X = z_temp.values
input_dimension = X.shape[1]
# Out:
# 20554.545012 MB
# (342, 167042)

# %% [markdown]
# ## Splitting

# %%
X = X.astype(np.float32)
X_train, X_test = train_test_split(X, test_size=0.1, random_state=27)

train_loader = DataLoader(TensorDataset(torch.from_numpy(X_train)), batch_size=64, shuffle=True)
test_loader = DataLoader(TensorDataset(torch.from_numpy(X_test)), batch_size=64, shuffle=False)

# %% [markdown]
# ## The Architecture

# %%
class VariationalAutoencoder(nn.Module):
    def __init__(self, input_dim, latent_dim):
        super().__init__()

        # Encoder for mean and logvar
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 512),
            nn.BatchNorm1d(512),
            nn.Dropout(0.1),
            nn.LeakyReLU(),

            nn.Linear(512, 32),
            nn.BatchNorm1d(32),
            nn.Dropout(0.1),
            nn.LeakyReLU()
        )
        self.fc_mean = nn.Linear(32, latent_dim)
        self.fc_logvar = nn.Linear(32, latent_dim)

        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 32),
            nn.BatchNorm1d(32),
            nn.LeakyReLU(),

            nn.Linear(32, 512),
            nn.BatchNorm1d(512),
            nn.LeakyReLU(),

            nn.Linear(512, input_dim)
        )

    def reparameterize(self, mean, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mean + eps * std

    def forward(self, x):
        h = self.encoder(x)
        z_mean = self.fc_mean(h)
        z_logvar = self.fc_logvar(h)
        z = self.reparameterize(z_mean, z_logvar)
        x_recon = self.decoder(z)
        return x_recon, z_mean, z_logvar

# %% [markdown]
# ## Training Loop

# %%
def train(num_epochs: int, kl_annealing_epochs: int = 50, bint = 100):
    torch.cuda.empty_cache()

    train_losses = []
    val_losses = []
    train_recon_list = []
    train_kl_list = []
    val_recon_list = []
    val_kl_list = []

    for epoch in range(num_epochs):
        beta = min(bint, epoch / kl_annealing_epochs * bint)

        model.train()
        running_train_recon = 0.0
        running_train_kl = 0.0

        for batch in train_loader:
            x = batch[0].to(device).float()

            optimizer.zero_grad()
            x_recon, z_mean, z_logvar = model(x)

            kl_loss = -0.5 * torch.sum(1 + z_logvar - z_mean.pow(2) - z_logvar.exp(), dim=1)
            kl_loss = torch.mean(kl_loss)

            recon_loss = reconstruction_loss_fn(x_recon, x)

            loss = recon_loss + beta * kl_loss
            loss.backward()
            optimizer.step()

            running_train_recon += recon_loss.item() * x.size(0)
            running_train_kl += kl_loss.item() * x.size(0)

        train_recon = running_train_recon / len(train_loader.dataset)
        train_kl = running_train_kl / len(train_loader.dataset)
        train_loss = train_recon + beta * train_kl

        train_losses.append(train_loss)
        train_recon_list.append(train_recon)
        train_kl_list.append(train_kl)

        # Validation
        model.eval()
        running_val_recon = 0.0
        running_val_kl = 0.0

        with torch.no_grad():
            for batch in test_loader:
                x = batch[0].to(device).float()
                x_recon, z_mean, z_logvar = model(x)

                kl_loss = -0.5 * torch.sum(1 + z_logvar - z_mean.pow(2) - z_logvar.exp(), dim=1)
                kl_loss = torch.mean(kl_loss)

                recon_loss = reconstruction_loss_fn(x_recon, x)

                running_val_recon += recon_loss.item() * x.size(0)
                running_val_kl += kl_loss.item() * x.size(0)

        val_recon = running_val_recon / len(test_loader.dataset)
        val_kl = running_val_kl / len(test_loader.dataset)
        val_loss = val_recon + beta * val_kl

        val_losses.append(val_loss)
        val_recon_list.append(val_recon)
        val_kl_list.append(val_kl)

        if (epoch+1) % 10 == 0:
            print(
                f"Epoch {epoch+1}/{num_epochs} | "
                f"β: {beta:.3f} | "
                f"Train Loss: {train_loss:.4f} (Recon: {train_recon:.4f}, KL: {train_kl:.4f}) | "
                f"Val Loss: {val_loss:.4f} (Recon: {val_recon:.4f}, KL: {val_kl:.4f})"
            )

    return train_losses, val_losses, train_recon_list, val_recon_list, train_kl_list, val_kl_list

# %% [markdown]
# ## Setup

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Training using device: {device}')

# Dein VAE statt AE
model = VariationalAutoencoder(input_dim=input_dimension, latent_dim=3).to(device)
model = model.float()

summary(model, input_size=(1, X.shape[1]))

optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
reconstruction_loss_fn = nn.MSELoss(reduction='mean')
# Out:
# Training using device: cuda

# %%
train_losses, val_losses, train_recons, val_recons, train_kls, val_kls = train(800,200, 0.08)
# train_losses, val_losses, train_recons, val_recons, train_kls, val_kls = train(800,200, 0.06)
# Out:
# Epoch 10/800 | β: 0.004 | Train Loss: 0.8988 (Recon: 0.8928, KL: 1.6427) | Val Loss: 0.8836 (Recon: 0.8719, KL: 3.2673)
# Epoch 20/800 | β: 0.008 | Train Loss: 0.8244 (Recon: 0.8086, KL: 2.0792) | Val Loss: 0.8403 (Recon: 0.8131, KL: 3.5809)
# Epoch 30/800 | β: 0.012 | Train Loss: 0.7940 (Recon: 0.7675, KL: 2.2866) | Val Loss: 0.8290 (Recon: 0.7887, KL: 3.4750)
# Epoch 40/800 | β: 0.016 | Train Loss: 0.7817 (Recon: 0.7431, KL: 2.4719) | Val Loss: 0.8268 (Recon: 0.7681, KL: 3.7588)
# Epoch 50/800 | β: 0.020 | Train Loss: 0.7788 (Recon: 0.7298, KL: 2.4970) | Val Loss: 0.8269 (Recon: 0.7542, KL: 3.7093)
# Epoch 60/800 | β: 0.024 | Train Loss: 0.7726 (Recon: 0.7113, KL: 2.5973) | Val Loss: 0.8345 (Recon: 0.7544, KL: 3.3938)
# Epoch 70/800 | β: 0.028 | Train Loss: 0.7726 (Recon: 0.7023, KL: 2.5498) | Val Loss: 0.8596 (Recon: 0.7637, KL: 3.4747)
# Epoch 80/800 | β: 0.032 | Train Loss: 0.7620 (Recon: 0.6824, KL: 2.5186) | Val Loss: 0.8510 (Recon: 0.7400, KL: 3.5135)
# Epoch 90/800 | β: 0.036 | Train Loss: 0.7862 (Recon: 0.7002, KL: 2.4167) | Val Loss: 0.8626 (Recon: 0.7431, KL: 3.3565)
# Epoch 100/800 | β: 0.040 | Train Loss: 0.7897 (Recon: 0.6938, KL: 2.4224) | Val Loss: 0.8765 (Recon: 0.7537, KL: 3.1009)
# Epoch 110/800 | β: 0.044 | Train Loss: 0.7936 (Recon: 0.6931, KL: 2.3050) | Val Loss: 0.8874 (Recon: 0.7501, KL: 3.1501)
# Epoch 120/800 | β: 0.048 | Train Loss: 0.8012 (Recon: 0.6972, KL: 2.1849) | Val Loss: 0.9204 (Recon: 0.7756, KL: 3.0418)
# Epoch 130/800 | β: 0.052 | Train Loss: 0.8164 (Recon: 0.7023, KL: 2.2105) | Val Loss: 0.8707 (Recon: 0.7184, KL: 2.9511)
# Epoch 140/800 | β: 0.056 | Train Loss: 0.8009 (Recon: 0.6777, KL: 2.2159) | Val Loss: 0.8917 (Recon: 0.7236, KL: 3.0247)
# Epoch 150/800 | β: 0.060 | Train Loss: 0.8102 (Recon: 0.6837, KL: 2.1225) | Val Loss: 0.9026 (Recon: 0.7212, KL: 3.0430)
# Epoch 160/800 | β: 0.064 | Train Loss: 0.8385 (Recon: 0.7057, KL: 2.0872) | Val Loss: 0.8883 (Recon: 0.6989, KL: 2.9774)
# Epoch 170/800 | β: 0.068 | Train Loss: 0.8208 (Recon: 0.6761, KL: 2.1399) | Val Loss: 0.9042 (Recon: 0.7012, KL: 3.0022)
# Epoch 180/800 | β: 0.072 | Train Loss: 0.8227 (Recon: 0.6735, KL: 2.0833) | Val Loss: 0.9104 (Recon: 0.7073, KL: 2.8363)
# Epoch 190/800 | β: 0.076 | Train Loss: 0.8422 (Recon: 0.6892, KL: 2.0239) | Val Loss: 0.9329 (Recon: 0.7131, KL: 2.9068)
# Epoch 200/800 | β: 0.080 | Train Loss: 0.8380 (Recon: 0.6706, KL: 2.1031) | Val Loss: 0.9269 (Recon: 0.6950, KL: 2.9139)
# Epoch 210/800 | β: 0.080 | Train Loss: 0.8303 (Recon: 0.6685, KL: 2.0226) | Val Loss: 0.9209 (Recon: 0.6941, KL: 2.8341)
# Epoch 220/800 | β: 0.080 | Train Loss: 0.8221 (Recon: 0.6600, KL: 2.0260) | Val Loss: 0.9158 (Recon: 0.6846, KL: 2.8899)
# Epoch 230/800 | β: 0.080 | Train Loss: 0.8660 (Recon: 0.7044, KL: 2.0202) | Val Loss: 0.9128 (Recon: 0.6915, KL: 2.7661)
# Epoch 240/800 | β: 0.080 | Train Loss: 0.8483 (Recon: 0.6860, KL: 2.0281) | Val Loss: 0.8835 (Recon: 0.6557, KL: 2.8481)
# Epoch 250/800 | β: 0.080 | Train Loss: 0.8097 (Recon: 0.6433, KL: 2.0805) | Val Loss: 0.9187 (Recon: 0.6868, KL: 2.8991)
# Epoch 260/800 | β: 0.080 | Train Loss: 0.8209 (Recon: 0.6531, KL: 2.0964) | Val Loss: 0.9184 (Recon: 0.6900, KL: 2.8548)
# Epoch 270/800 | β: 0.080 | Train Loss: 0.8269 (Recon: 0.6577, KL: 2.1150) | Val Loss: 0.9258 (Recon: 0.6971, KL: 2.8581)
# Epoch 280/800 | β: 0.080 | Train Loss: 0.8128 (Recon: 0.6367, KL: 2.2012) | Val Loss: 0.8927 (Recon: 0.6571, KL: 2.9456)
# Epoch 290/800 | β: 0.080 | Train Loss: 0.8186 (Recon: 0.6462, KL: 2.1555) | Val Loss: 0.8978 (Recon: 0.6638, KL: 2.9248)
# Epoch 300/800 | β: 0.080 | Train Loss: 0.8235 (Recon: 0.6511, KL: 2.1541) | Val Loss: 0.9335 (Recon: 0.7020, KL: 2.8943)
# Epoch 310/800 | β: 0.080 | Train Loss: 0.8293 (Recon: 0.6573, KL: 2.1494) | Val Loss: 0.8923 (Recon: 0.6502, KL: 3.0259)
# Epoch 320/800 | β: 0.080 | Train Loss: 0.8160 (Recon: 0.6430, KL: 2.1624) | Val Loss: 0.8963 (Recon: 0.6600, KL: 2.9541)
# Epoch 330/800 | β: 0.080 | Train Loss: 0.8274 (Recon: 0.6534, KL: 2.1754) | Val Loss: 0.8616 (Recon: 0.6171, KL: 3.0569)
# Epoch 340/800 | β: 0.080 | Train Loss: 0.8133 (Recon: 0.6348, KL: 2.2317) | Val Loss: 0.8756 (Recon: 0.6309, KL: 3.0590)
# Epoch 350/800 | β: 0.080 | Train Loss: 0.8050 (Recon: 0.6280, KL: 2.2118) | Val Loss: 0.9009 (Recon: 0.6567, KL: 3.0529)
# Epoch 360/800 | β: 0.080 | Train Loss: 0.8204 (Recon: 0.6408, KL: 2.2442) | Val Loss: 0.9153 (Recon: 0.6690, KL: 3.0780)
# Epoch 370/800 | β: 0.080 | Train Loss: 0.7991 (Recon: 0.6185, KL: 2.2577) | Val Loss: 0.8901 (Recon: 0.6506, KL: 2.9940)
# Epoch 380/800 | β: 0.080 | Train Loss: 0.8076 (Recon: 0.6257, KL: 2.2738) | Val Loss: 0.8796 (Recon: 0.6383, KL: 3.0154)
# Epoch 390/800 | β: 0.080 | Train Loss: 0.8179 (Recon: 0.6361, KL: 2.2725) | Val Loss: 0.8867 (Recon: 0.6423, KL: 3.0549)
# Epoch 400/800 | β: 0.080 | Train Loss: 0.8104 (Recon: 0.6261, KL: 2.3039) | Val Loss: 0.8934 (Recon: 0.6489, KL: 3.0572)
# Epoch 410/800 | β: 0.080 | Train Loss: 0.8199 (Recon: 0.6357, KL: 2.3029) | Val Loss: 0.9009 (Recon: 0.6544, KL: 3.0808)
# Epoch 420/800 | β: 0.080 | Train Loss: 0.8160 (Recon: 0.6326, KL: 2.2931) | Val Loss: 0.9182 (Recon: 0.6744, KL: 3.0473)
# Epoch 430/800 | β: 0.080 | Train Loss: 0.8248 (Recon: 0.6380, KL: 2.3349) | Val Loss: 0.9054 (Recon: 0.6530, KL: 3.1549)
# Epoch 440/800 | β: 0.080 | Train Loss: 0.8137 (Recon: 0.6250, KL: 2.3586) | Val Loss: 0.8770 (Recon: 0.6227, KL: 3.1790)
# Epoch 450/800 | β: 0.080 | Train Loss: 0.8166 (Recon: 0.6286, KL: 2.3491) | Val Loss: 0.8992 (Recon: 0.6477, KL: 3.1441)
# Epoch 460/800 | β: 0.080 | Train Loss: 0.8076 (Recon: 0.6191, KL: 2.3568) | Val Loss: 0.9258 (Recon: 0.6691, KL: 3.2086)
# Epoch 470/800 | β: 0.080 | Train Loss: 0.8074 (Recon: 0.6200, KL: 2.3424) | Val Loss: 0.8825 (Recon: 0.6272, KL: 3.1924)
# Epoch 480/800 | β: 0.080 | Train Loss: 0.8018 (Recon: 0.6160, KL: 2.3226) | Val Loss: 0.9340 (Recon: 0.6799, KL: 3.1765)
# Epoch 490/800 | β: 0.080 | Train Loss: 0.8081 (Recon: 0.6141, KL: 2.4257) | Val Loss: 0.9269 (Recon: 0.6711, KL: 3.1983)
# Epoch 500/800 | β: 0.080 | Train Loss: 0.8042 (Recon: 0.6108, KL: 2.4174) | Val Loss: 0.9295 (Recon: 0.6738, KL: 3.1959)
# Epoch 510/800 | β: 0.080 | Train Loss: 0.7815 (Recon: 0.5876, KL: 2.4232) | Val Loss: 0.9296 (Recon: 0.6702, KL: 3.2423)
# Epoch 520/800 | β: 0.080 | Train Loss: 0.8044 (Recon: 0.6127, KL: 2.3961) | Val Loss: 0.8789 (Recon: 0.6243, KL: 3.1824)
# Epoch 530/800 | β: 0.080 | Train Loss: 0.8098 (Recon: 0.6150, KL: 2.4351) | Val Loss: 0.9260 (Recon: 0.6615, KL: 3.3057)
# Epoch 540/800 | β: 0.080 | Train Loss: 0.8046 (Recon: 0.6117, KL: 2.4119) | Val Loss: 0.8782 (Recon: 0.6194, KL: 3.2349)
# Epoch 550/800 | β: 0.080 | Train Loss: 0.8043 (Recon: 0.6075, KL: 2.4601) | Val Loss: 0.9068 (Recon: 0.6420, KL: 3.3103)
# Epoch 560/800 | β: 0.080 | Train Loss: 0.7911 (Recon: 0.5948, KL: 2.4541) | Val Loss: 0.8720 (Recon: 0.6131, KL: 3.2357)
# Epoch 570/800 | β: 0.080 | Train Loss: 0.8076 (Recon: 0.6095, KL: 2.4760) | Val Loss: 0.9360 (Recon: 0.6769, KL: 3.2382)
# Epoch 580/800 | β: 0.080 | Train Loss: 0.8341 (Recon: 0.6423, KL: 2.3982) | Val Loss: 0.9163 (Recon: 0.6535, KL: 3.2845)
# Epoch 590/800 | β: 0.080 | Train Loss: 0.8176 (Recon: 0.6180, KL: 2.4948) | Val Loss: 0.9051 (Recon: 0.6406, KL: 3.3059)
# Epoch 600/800 | β: 0.080 | Train Loss: 0.7925 (Recon: 0.5945, KL: 2.4749) | Val Loss: 0.8920 (Recon: 0.6261, KL: 3.3240)
# Epoch 610/800 | β: 0.080 | Train Loss: 0.8194 (Recon: 0.6206, KL: 2.4850) | Val Loss: 0.9143 (Recon: 0.6497, KL: 3.3068)
# Epoch 620/800 | β: 0.080 | Train Loss: 0.7954 (Recon: 0.5951, KL: 2.5041) | Val Loss: 0.9115 (Recon: 0.6415, KL: 3.3753)
# Epoch 630/800 | β: 0.080 | Train Loss: 0.8093 (Recon: 0.6125, KL: 2.4602) | Val Loss: 0.8809 (Recon: 0.6095, KL: 3.3927)
# Epoch 640/800 | β: 0.080 | Train Loss: 0.7874 (Recon: 0.5909, KL: 2.4556) | Val Loss: 0.9180 (Recon: 0.6527, KL: 3.3159)
# Epoch 650/800 | β: 0.080 | Train Loss: 0.8001 (Recon: 0.5987, KL: 2.5178) | Val Loss: 0.8746 (Recon: 0.6047, KL: 3.3732)
# Epoch 660/800 | β: 0.080 | Train Loss: 0.7888 (Recon: 0.5863, KL: 2.5312) | Val Loss: 0.8941 (Recon: 0.6248, KL: 3.3666)
# Epoch 670/800 | β: 0.080 | Train Loss: 0.7907 (Recon: 0.5856, KL: 2.5637) | Val Loss: 0.8810 (Recon: 0.6106, KL: 3.3806)
# Epoch 680/800 | β: 0.080 | Train Loss: 0.8027 (Recon: 0.5980, KL: 2.5597) | Val Loss: 0.9037 (Recon: 0.6288, KL: 3.4362)
# Epoch 690/800 | β: 0.080 | Train Loss: 0.7928 (Recon: 0.5898, KL: 2.5385) | Val Loss: 0.8783 (Recon: 0.6169, KL: 3.2674)
# Epoch 700/800 | β: 0.080 | Train Loss: 0.7861 (Recon: 0.5819, KL: 2.5528) | Val Loss: 0.9176 (Recon: 0.6462, KL: 3.3924)
# Epoch 710/800 | β: 0.080 | Train Loss: 0.7834 (Recon: 0.5751, KL: 2.6034) | Val Loss: 0.8898 (Recon: 0.6220, KL: 3.3464)
# Epoch 720/800 | β: 0.080 | Train Loss: 0.7996 (Recon: 0.5929, KL: 2.5837) | Val Loss: 0.8824 (Recon: 0.6106, KL: 3.3970)
# Epoch 730/800 | β: 0.080 | Train Loss: 0.8052 (Recon: 0.6039, KL: 2.5168) | Val Loss: 0.8853 (Recon: 0.6121, KL: 3.4148)
# Epoch 740/800 | β: 0.080 | Train Loss: 0.7853 (Recon: 0.5795, KL: 2.5735) | Val Loss: 0.8848 (Recon: 0.6171, KL: 3.3453)
# Epoch 750/800 | β: 0.080 | Train Loss: 0.7920 (Recon: 0.5842, KL: 2.5982) | Val Loss: 0.8759 (Recon: 0.6105, KL: 3.3183)
# Epoch 760/800 | β: 0.080 | Train Loss: 0.7737 (Recon: 0.5658, KL: 2.5991) | Val Loss: 0.8800 (Recon: 0.6105, KL: 3.3689)
# Epoch 770/800 | β: 0.080 | Train Loss: 0.7988 (Recon: 0.6006, KL: 2.4772) | Val Loss: 0.9111 (Recon: 0.6461, KL: 3.3120)
# Epoch 780/800 | β: 0.080 | Train Loss: 0.7840 (Recon: 0.5746, KL: 2.6170) | Val Loss: 0.8721 (Recon: 0.5944, KL: 3.4705)
# Epoch 790/800 | β: 0.080 | Train Loss: 0.8003 (Recon: 0.5901, KL: 2.6270) | Val Loss: 0.8816 (Recon: 0.6082, KL: 3.4172)
# Epoch 800/800 | β: 0.080 | Train Loss: 0.8031 (Recon: 0.5975, KL: 2.5697) | Val Loss: 0.9074 (Recon: 0.6363, KL: 3.3883)

# %% [markdown]
# ## Evaluation

# %%
helper_functions.plot_metrics([(train_losses, "Train Loss"), (val_losses, "Validation Loss")], "Loss")
helper_functions.plot_metrics([(train_recons, "Train MSE-Scores"), (val_recons, "Validation MSE-Scores")], "MSE Score")
helper_functions.plot_metrics([(train_kls, "Train KL-Scores"), (val_kls, "Validation KL-Scores")], "KL-Score")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
model.eval()

latents_mu = []
latents_logvar = []

with torch.no_grad():
    for batch in test_loader:
        x = batch[0].to(device).float()
        _, mu, logvar = model(x)
        latents_mu.append(mu.cpu())
        latents_logvar.append(logvar.cpu())

mu_all = torch.cat(latents_mu, dim=0)           # shape: (n_samples, latent_dim)
logvar_all = torch.cat(latents_logvar, dim=0)   # shape: (n_samples, latent_dim)

# Statistics
mu_std = mu_all.std(dim=0)
logvar_mean = logvar_all.mean(dim=0)
logvar_std = logvar_all.std(dim=0)

print("Std of mu per latent dim:")
print(mu_std)

print("\nMean of logvar per latent dim:")
print(logvar_mean)

print("\nStd of logvar per latent dim:")
print(logvar_std)
# Out:
# Std of mu per latent dim:
# tensor([0.7510, 0.8352, 0.8420])
#
# Mean of logvar per latent dim:
# tensor([-1.6833, -1.5366, -1.8595])
#
# Std of logvar per latent dim:
# tensor([0.3255, 0.2147, 0.2905])

# %%
torch.save(model.state_dict(), "VAE.pth")
