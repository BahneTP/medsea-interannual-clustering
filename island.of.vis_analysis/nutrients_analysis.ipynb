# %% [markdown]
# # Nutrients

# %%
import xarray as xr
import numpy as np

import helper_functions
import importlib
importlib.reload(helper_functions)
# Out:
# <module 'helper_functions' from 'c:\\Croatia\\island.of.vis_analysis\\helper_functions.py'>

# %%
nutrients = xr.open_dataset("data/nutrients_combined.nc")

years = [1998, 2001, 2004, 2007, 2010, 2013, 2016, 2019, 2022, 2024]

# %% [markdown]
# ### Chlorophyll

# %%
helper_functions.plot_hovmoeller_grid(
    ds=nutrients,
    var_name='chl',
    years=years,
    cmin = 0.1,
    cmax = 1,
    contour_levels=[38.2, 38.4, 38.6, 38.7, 38.8],
    mean_space=True,
    sigma=5.0,
    nrows=5,
    ncols=2,
    anomaly=False,
    logscale=True,
    cbartitle="Chlorophyll (mg/m³)",
    yearcolor="white"
)
# Out:
# c:\Croatia\island.of.vis_analysis\helper_functions.py:300: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)
# c:\Croatia\island.of.vis_analysis\helper_functions.py:300: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)

# %%
importlib.reload(helper_functions)
helper_functions.plot_anomalies(nutrients, "chl", -2, 2, "Chlorophyll Anomaly (mg/m³)", [10, 75], 730, False, [("chl", "Chlorophyll")])

# %% [markdown]
# ### Nitrates

# %%
helper_functions.plot_hovmoeller_grid(
    ds=nutrients,
    var_name='no3',
    years=years,
    cmin = 0.2,
    cmax = 1,
    contour_levels=[38.2, 38.4, 38.6, 38.7, 38.8],
    mean_space=True,
    sigma=5.0,
    nrows=5,
    ncols=2,
    anomaly=False,
    logscale=False,
    cbartitle="Nitrate mmol/m³",
    yearcolor="white"
)
# Out:
# c:\Croatia\island.of.vis_analysis\helper_functions.py:300: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)
# c:\Croatia\island.of.vis_analysis\helper_functions.py:300: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)

# %%
importlib.reload(helper_functions)
helper_functions.plot_anomalies(nutrients, "no3", -2, 2, "Nitrate (mmol/m³)", [10, 75], 730, False, [("no3", "Nutrients")])

# %% [markdown]
# ### Net Primary Production Value

# %%
helper_functions.plot_hovmoeller_grid(
    ds=nutrients,
    var_name='nppv',
    years=years,
    cmin = 0,
    cmax = 10,
    contour_levels=[38.2, 38.4, 38.6, 38.7, 38.8],
    mean_space=True,
    sigma=5.0,
    nrows=5,
    ncols=2,
    anomaly=False,
    logscale=False,
    cbartitle="NPPV (mg/m³/day)",
    yearcolor="white"
)
# Out:
# c:\Croatia\island.of.vis_analysis\helper_functions.py:300: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)
# c:\Croatia\island.of.vis_analysis\helper_functions.py:300: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)

# %%
helper_functions.plot_anomalies(nutrients, "nppv", -2, 2, "NPPV Anomaly (mg/m³/day)", [10, 75], 730, False, [("nppv", "NPPV")])

# %% [markdown]
# ### Oxygen

# %%
# helper_functions.plot_hovmoeller_grid(
#     ds=nutrients,
#     var_name='o2',
#     years=years,
#     cmin = 220,
#     cmax = 260,
#     contour_levels=[38.2, 38.4, 38.6, 38.7, 38.8],
#     mean_space=True,
#     sigma=5.0,
#     nrows=5,
#     ncols=2,
#     anomaly=False,
#     logscale=False,
#     cbartitle="Oxygen (mmol/m³)",
#     yearcolor="white"
# )

# %%
# helper_functions.plot_anomalies(nutrients, "o2", -2, 2, "Oxygen (mmol/m³)", [75, 10], 730, False)

# %% [markdown]
# ### Phosphates

# %%
importlib.reload(helper_functions)
helper_functions.plot_hovmoeller_grid(
    ds=nutrients,
    var_name='po4',
    years=years,
    cmin = 0,
    cmax = 0.03,
    contour_levels=[38.2, 38.4, 38.6, 38.7, 38.8],
    mean_space=True,
    sigma=5.0,
    nrows=5,
    ncols=2,
    anomaly=False,
    logscale=False,
    cbartitle="Phosphate (mmol/m³)",
    yearcolor="white"
)
# Out:
# c:\Croatia\island.of.vis_analysis\helper_functions.py:300: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)
# c:\Croatia\island.of.vis_analysis\helper_functions.py:300: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)

# %%
helper_functions.plot_anomalies(nutrients, "po4", -2, 2, "Phosphate Anomaly (mmol/m³)", [10, 75], 730, False, [("po4", "Phosphate")])

# %% [markdown]
# ### Silicates

# %%
helper_functions.plot_hovmoeller_grid(
    ds=nutrients,
    var_name='si',
    years=years,
    cmin = 3,
    cmax = 6,
    contour_levels=[38.2, 38.4, 38.6, 38.7, 38.8],
    mean_space=True,
    sigma=5.0,
    nrows=5,
    ncols=2,
    anomaly=False,
    logscale=False,
    cbartitle="Silicate (mmol/m³)",
    yearcolor="white"
)
# Out:
# c:\Croatia\island.of.vis_analysis\helper_functions.py:300: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)
# c:\Croatia\island.of.vis_analysis\helper_functions.py:300: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)

# %%
helper_functions.plot_anomalies(nutrients, "si", -2, 2, "Silicate Anomaly (mmol/m³)", [10, 75], 730, False, [("si", "Silicate")])

# %% [markdown]
# ###
