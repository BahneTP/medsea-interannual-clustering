# %%
import xarray as xr

ds1 = xr.open_dataset("data/nutrients_combined.nc")
ds1 = ds1.sel(time=slice("1998-01-01", "2025-04-30"))
ds2 = xr.open_dataset("data/thermohaline_combined.nc")
ds2 = ds2.sel(time=slice("1998-01-01", "2025-04-30"))

# ds = xr.merge([ds1, ds2])

# %%
print(ds)
# Out:
# <xarray.Dataset> Size: 97MB
# Dimensions:    (time: 14069, latitude: 2, longitude: 2, depth: 43)
# Coordinates:
#   * time       (time) datetime64[ns] 113kB 1987-01-01 1987-01-02 ... 2025-07-08
#   * latitude   (latitude) float32 8B 42.98 43.0
#   * longitude  (longitude) float32 8B 16.0 16.04
#   * depth      (depth) float32 172B 0.51 1.018 1.56 2.67 ... 72.62 77.61 86.93
# Data variables:
#     chl        (time, depth, latitude, longitude) float32 10MB nan nan ... nan
#     no3        (time, depth, latitude, longitude) float32 10MB nan nan ... nan
#     nppv       (time, depth, latitude, longitude) float32 10MB nan nan ... nan
#     o2         (time, depth, latitude, longitude) float32 10MB nan nan ... nan
#     po4        (time, depth, latitude, longitude) float32 10MB nan nan ... nan
#     si         (time, depth, latitude, longitude) float32 10MB nan nan ... nan
#     uo         (time, depth, latitude, longitude) float32 10MB nan nan ... nan
# ...

# %%
print(ds1.dims)
print(ds2.dims)
# Out:
# FrozenMappingWarningOnValuesAccess({'time': 9982, 'depth': 23, 'latitude': 1, 'longitude': 1})
# FrozenMappingWarningOnValuesAccess({'time': 9832, 'depth': 20, 'latitude': 1, 'longitude': 1})
