# %% [markdown]
# # Nutrients

# %%
import xarray as xr
import numpy as np

import helper_functions
import importlib
importlib.reload(helper_functions)
# Out:
# <module 'helper_functions' from 'c:\\Croatia\\island.of.vis_analysis\\helper_functions.py'>

# %%
nutrients = xr.open_dataset("data/nutrients_combined.nc")
# print(nutrients)

# %% [markdown]
# ### Chlorophyll

# %%
helper_functions.plot_hovmoeller_grid(
    ds=nutrients,
    var_name='chl',
    years=[1995, 1997, 2001, 2003, 2005, 2008, 2011, 2016, 2020, 2024],
    cmin = 0.1,
    cmax = 1,
    contour_levels=[38.2, 38.4, 38.6, 38.7, 38.8],
    mean_space=True,
    sigma=5.0,
    nrows=5,
    ncols=2,
    anomaly=False,
    logscale=True,
    cbartitle="Chlorophyll (mg/m³)",
    yearcolor="white"
)
# Out:
# c:\Croatia\island.of.vis_analysis\helper_functions.py:182: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)
# c:\Croatia\island.of.vis_analysis\helper_functions.py:182: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)

# %%
helper_functions.plot_anomalies(nutrients, "chl", -0.2, 0.2, "Chlorophyll Anomaly (mg/m³)")

# %% [markdown]
# ### Nitrates

# %%
helper_functions.plot_hovmoeller_grid(
    ds=nutrients,
    var_name='no3',
    years=[1995, 1997, 2001, 2003, 2005, 2008, 2011, 2016, 2020, 2024],
    cmin = 0.2,
    cmax = 1,
    contour_levels=[38.2, 38.4, 38.6, 38.7, 38.8],
    mean_space=True,
    sigma=5.0,
    nrows=5,
    ncols=2,
    anomaly=False,
    logscale=False,
    cbartitle="Nitrate mmol/m³",
    yearcolor="white"
)
# Out:
# c:\Croatia\island.of.vis_analysis\helper_functions.py:182: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)
# c:\Croatia\island.of.vis_analysis\helper_functions.py:182: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)

# %%
helper_functions.plot_anomalies(nutrients, "no3", -0.5, 0.5, "Nitrate (mmol/m³)")

# %% [markdown]
# ### Net Primary Production Value

# %%
helper_functions.plot_hovmoeller_grid(
    ds=nutrients,
    var_name='nppv',
    years=[1995, 1997, 2001, 2003, 2005, 2008, 2011, 2016, 2020, 2024],
    cmin = 0,
    cmax = 10,
    contour_levels=[38.2, 38.4, 38.6, 38.7, 38.8],
    mean_space=True,
    sigma=5.0,
    nrows=5,
    ncols=2,
    anomaly=False,
    logscale=False,
    cbartitle="NPPV (mg/m³/day)",
    yearcolor="white"
)
# Out:
# c:\Croatia\island.of.vis_analysis\helper_functions.py:182: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)
# c:\Croatia\island.of.vis_analysis\helper_functions.py:182: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)

# %%
helper_functions.plot_anomalies(nutrients, "nppv", -3, 3, "NPPV Anomaly (mg/m³/day)")

# %% [markdown]
# ### Oxygen

# %%
helper_functions.plot_hovmoeller_grid(
    ds=nutrients,
    var_name='o2',
    years=[1995, 1997, 2001, 2003, 2005, 2008, 2011, 2016, 2020, 2024],
    cmin = 220,
    cmax = 260,
    contour_levels=[38.2, 38.4, 38.6, 38.7, 38.8],
    mean_space=True,
    sigma=5.0,
    nrows=5,
    ncols=2,
    anomaly=False,
    logscale=False,
    cbartitle="Oxygen (mmol/m³)",
    yearcolor="white"
)
# Out:
# c:\Croatia\island.of.vis_analysis\helper_functions.py:182: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)
# c:\Croatia\island.of.vis_analysis\helper_functions.py:182: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)

# %%
helper_functions.plot_anomalies(nutrients, "o2", -10, 10, "Oxygen (mmol/m³)")

# %% [markdown]
# ### Phosphates

# %%
importlib.reload(helper_functions)
helper_functions.plot_hovmoeller_grid(
    ds=nutrients,
    var_name='po4',
    years=[1995, 1997, 2001, 2003, 2005, 2008, 2011, 2016, 2020, 2024],
    cmin = 0,
    cmax = 0.03,
    contour_levels=[38.2, 38.4, 38.6, 38.7, 38.8],
    mean_space=True,
    sigma=5.0,
    nrows=5,
    ncols=2,
    anomaly=False,
    logscale=False,
    cbartitle="Phosphate (mmol/m³)",
    yearcolor="white"
)
# Out:
# c:\Croatia\island.of.vis_analysis\helper_functions.py:182: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)
# c:\Croatia\island.of.vis_analysis\helper_functions.py:182: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)

# %%
helper_functions.plot_anomalies(nutrients, "po4", -0.02, 0.02, "Phosphate Anomaly (mmol/m³)")

# %% [markdown]
# ### Silicates

# %%
helper_functions.plot_hovmoeller_grid(
    ds=nutrients,
    var_name='si',
    years=[1995, 1997, 2001, 2003, 2005, 2008, 2011, 2016, 2020, 2024],
    cmin = 3,
    cmax = 6,
    contour_levels=[38.2, 38.4, 38.6, 38.7, 38.8],
    mean_space=True,
    sigma=5.0,
    nrows=5,
    ncols=2,
    anomaly=False,
    logscale=False,
    cbartitle="Silicate (mmol/m³)",
    yearcolor="white"
)
# Out:
# c:\Croatia\island.of.vis_analysis\helper_functions.py:182: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)
# c:\Croatia\island.of.vis_analysis\helper_functions.py:182: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)

# %%
helper_functions.plot_anomalies(nutrients, "si", -2, 2, "Silicate Anomaly (mmol/m³)")

# %% [markdown]
# ###
