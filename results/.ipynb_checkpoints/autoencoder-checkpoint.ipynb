# %% [markdown]
# # Autoencoder
# This notebook makes use of the **Autoencoder**, which is used to reduce the dimensionality of our dataset in a non-linear way. Furthermore, we then apply **k-means Clustering** as in our last notebook in our new created **Latent Space** in lower dimension. We do so, to get rid of less important variables and achieve a better Clustering.

# %%
# !pip install cartopy xarray matplotlib netCDF4 torch
# Out:
# Collecting cartopy
#   Using cached Cartopy-0.24.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.9 kB)
# Collecting xarray
#   Using cached xarray-2025.6.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.11/site-packages (3.8.4)
# Collecting netCDF4
#   Using cached netCDF4-1.7.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting torch
#   Using cached torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.11/site-packages (from cartopy) (1.26.4)
# Collecting shapely>=1.8 (from cartopy)
#   Using cached shapely-2.1.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: packaging>=21 in /opt/conda/lib/python3.11/site-packages (from cartopy) (24.0)
# Collecting pyshp>=2.3 (from cartopy)
#   Using cached pyshp-2.3.1-py2.py3-none-any.whl.metadata (55 kB)
# Collecting pyproj>=3.3.1 (from cartopy)
#   Using cached pyproj-3.7.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Requirement already satisfied: pandas>=2.1 in /opt/conda/lib/python3.11/site-packages (from xarray) (2.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (2.9.0)
# Collecting cftime (from netCDF4)
#   Using cached cftime-1.6.4.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from netCDF4) (2024.2.2)
# Collecting filelock (from torch)
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/conda/lib/python3.11/site-packages (from torch) (4.11.0)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch) (2024.3.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch)
#   Using cached nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch)
#   Using cached nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch)
#   Using cached nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch)
#   Using cached nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch)
#   Using cached nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch)
#   Using cached nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch)
#   Using cached nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch)
#   Using cached nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch)
#   Using cached nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch)
#   Using cached nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch)
#   Using cached nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.1 (from torch)
#   Using cached triton-3.3.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /opt/conda/lib/python3.11/site-packages (from triton==3.3.1->torch) (69.5.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=2.1->xarray) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas>=2.1->xarray) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch) (2.1.5)
# Using cached Cartopy-0.24.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
# Using cached xarray-2025.6.1-py3-none-any.whl (1.3 MB)
# Using cached netCDF4-1.7.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.3 MB)
# Using cached torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl (821.2 MB)
# Using cached nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
# Using cached nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
# Using cached nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
# Using cached nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
# Using cached nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
# Using cached nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
# Using cached nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
# Using cached nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
# Using cached nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
# Using cached nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
# Using cached nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
# Using cached nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Using cached triton-3.3.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.7 MB)
# Using cached pyproj-3.7.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.5 MB)
# Using cached pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
# Using cached shapely-2.1.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached cftime-1.6.4.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
# Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Installing collected packages: nvidia-cusparselt-cu12, triton, sympy, shapely, pyshp, pyproj, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, filelock, cftime, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, netCDF4, xarray, nvidia-cusolver-cu12, cartopy, torch
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.12
#     Uninstalling sympy-1.12:
#       Successfully uninstalled sympy-1.12
# Successfully installed cartopy-0.24.1 cftime-1.6.4.post1 filelock-3.18.0 netCDF4-1.7.2 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 pyproj-3.7.1 pyshp-2.3.1 shapely-2.1.1 sympy-1.14.0 torch-2.7.1 triton-3.3.1 xarray-2025.6.1

# %%
import helper_functions
import importlib
from ipywidgets import FloatSlider
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from ipywidgets import interact, IntSlider
from sklearn.decomposition import PCA
import numpy as np
import pandas as pd
import matplotlib.dates as mdates
importlib.reload(helper_functions)

import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from torch.utils.data import DataLoader, TensorDataset

# %% [markdown]
# ## Data Loading & Preprocessing

# %%
ds = xr.open_dataset("/home/jovyan/spatiotemporal-mining-medsea/data/medsea.nc")
print(ds.nbytes / 1e6, "MB")

z_temp = helper_functions.preprocessing(ds, ["thetao", "so"], [50, 300, 1000], "location", -1)
X = z_temp.values
print(X.shape)
input_dimension = X.shape[1]
print(z_temp.nbytes / 1e6, "MB")
# Out:
# 20554.545012 MB
# (342, 167042)
# 457.026912 MB

# %% [markdown]
# ## Splitting

# %%
X = X.astype(np.float32)
X_train, X_test = train_test_split(X, test_size=0.1, random_state=27)

train_loader = DataLoader(TensorDataset(torch.from_numpy(X_train)), batch_size=32, shuffle=True)
test_loader = DataLoader(TensorDataset(torch.from_numpy(X_test)), batch_size=32, shuffle=False)

# %% [markdown]
# ## The Architecture

# %%
import torch
import torch.nn as nn

class Autoencoder(nn.Module):
    def __init__(self, input_dim, latent_dim):
        super().__init__()

        # Encoder
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 512),
            nn.BatchNorm1d(512),
            nn.Dropout(0.1),
            nn.LeakyReLU(),

            nn.Linear(512, 256),
            nn.BatchNorm1d(256),
            nn.Dropout(0.1),
            nn.LeakyReLU(),

            nn.Linear(256, latent_dim)
            # Kein ReLU hier – das Latent kann auch negativ sein
        )

        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 256),
            nn.BatchNorm1d(256),
            nn.LeakyReLU(),

            nn.Linear(256, 512),
            nn.BatchNorm1d(512),
            nn.LeakyReLU(),

            nn.Linear(512, input_dim)
            # KEINE Aktivierungsfunktion hier – du willst rekonstruieren, nicht beschneiden
        )

    def forward(self, x):
        z = self.encoder(x)
        return self.decoder(z)

# %% [markdown]
# ## Training Loop

# %%
def train(num_epochs: int):
    torch.cuda.empty_cache()

    train_losses = []
    val_losses = []
    for epoch in range(num_epochs):
        model.train()
        running_train_loss = 0.0
        for batch in train_loader:
            x = batch[0].to(device).float()
                    
            optimizer.zero_grad()
            x_recon = model(x)
            loss = loss_fn(x_recon, x)
            loss.backward()
            optimizer.step()
            running_train_loss += loss.item() * x.size(0)
    
        train_loss = running_train_loss / len(train_loader.dataset)
        train_losses.append(train_loss)
    
        # Validation
        model.eval()
        running_val_loss = 0.0
        with torch.no_grad():
            for batch in test_loader:
                x = batch[0].to(device).float()
                x_recon = model(x)
                loss = loss_fn(x_recon, x)
                running_val_loss += loss.item() * x.size(0)
    
        val_loss = running_val_loss / len(test_loader.dataset)
        val_losses.append(val_loss)
    
        print(f"Epoch {epoch+1}/{num_epochs} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")
    return train_losses, val_losses

# %% [markdown]
# ## Setup

# %%
model = Autoencoder(input_dim=input_dimension, latent_dim=3)
model = model.float()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Training using device: {device}')
model.to(device)
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Trainierbare Parameter: {total_params:,}")

optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
loss_fn = nn.MSELoss()
num_epochs = 200
train_losses, val_losses = train(num_epochs)
# Out:
# Training using device: cuda
# Trainierbare Parameter: 171,486,341
# Epoch 1/200 | Train Loss: 1.1224 | Val Loss: 0.9727
# Epoch 2/200 | Train Loss: 1.0105 | Val Loss: 0.9295
# Epoch 3/200 | Train Loss: 0.9128 | Val Loss: 0.8581
# Epoch 4/200 | Train Loss: 0.8267 | Val Loss: 0.8020
# Epoch 5/200 | Train Loss: 0.7742 | Val Loss: 0.7691
# Epoch 6/200 | Train Loss: 0.7365 | Val Loss: 0.7487
# Epoch 7/200 | Train Loss: 0.7161 | Val Loss: 0.7349
# Epoch 8/200 | Train Loss: 0.6993 | Val Loss: 0.7248
# Epoch 9/200 | Train Loss: 0.6899 | Val Loss: 0.7171
# Epoch 10/200 | Train Loss: 0.6684 | Val Loss: 0.7084
# Epoch 11/200 | Train Loss: 0.6719 | Val Loss: 0.6997
# Epoch 12/200 | Train Loss: 0.6705 | Val Loss: 0.6919
# Epoch 13/200 | Train Loss: 0.6529 | Val Loss: 0.6872
# Epoch 14/200 | Train Loss: 0.6433 | Val Loss: 0.6785
# Epoch 15/200 | Train Loss: 0.6464 | Val Loss: 0.6728
# Epoch 16/200 | Train Loss: 0.6334 | Val Loss: 0.6678
# Epoch 17/200 | Train Loss: 0.6273 | Val Loss: 0.6589
# Epoch 18/200 | Train Loss: 0.6236 | Val Loss: 0.6561
# Epoch 19/200 | Train Loss: 0.6192 | Val Loss: 0.6494
# Epoch 20/200 | Train Loss: 0.6166 | Val Loss: 0.6443
# Epoch 21/200 | Train Loss: 0.6017 | Val Loss: 0.6364
# Epoch 22/200 | Train Loss: 0.6036 | Val Loss: 0.6324
# Epoch 23/200 | Train Loss: 0.6060 | Val Loss: 0.6263
# Epoch 24/200 | Train Loss: 0.5972 | Val Loss: 0.6197
# Epoch 25/200 | Train Loss: 0.5959 | Val Loss: 0.6140
# Epoch 26/200 | Train Loss: 0.5890 | Val Loss: 0.6092
# Epoch 27/200 | Train Loss: 0.5899 | Val Loss: 0.6043
# Epoch 28/200 | Train Loss: 0.5716 | Val Loss: 0.5981
# Epoch 29/200 | Train Loss: 0.5751 | Val Loss: 0.5935
# Epoch 30/200 | Train Loss: 0.5694 | Val Loss: 0.5905
# Epoch 31/200 | Train Loss: 0.5692 | Val Loss: 0.5870
# Epoch 32/200 | Train Loss: 0.5601 | Val Loss: 0.5847
# Epoch 33/200 | Train Loss: 0.5564 | Val Loss: 0.5813
# Epoch 34/200 | Train Loss: 0.5669 | Val Loss: 0.5794
# Epoch 35/200 | Train Loss: 0.5526 | Val Loss: 0.5764
# Epoch 36/200 | Train Loss: 0.5590 | Val Loss: 0.5718
# Epoch 37/200 | Train Loss: 0.5733 | Val Loss: 0.5722
# Epoch 38/200 | Train Loss: 0.5514 | Val Loss: 0.5693
# Epoch 39/200 | Train Loss: 0.5376 | Val Loss: 0.5674
# Epoch 40/200 | Train Loss: 0.5475 | Val Loss: 0.5650
# Epoch 41/200 | Train Loss: 0.5361 | Val Loss: 0.5628
# Epoch 42/200 | Train Loss: 0.5317 | Val Loss: 0.5610
# Epoch 43/200 | Train Loss: 0.5383 | Val Loss: 0.5604
# Epoch 44/200 | Train Loss: 0.5505 | Val Loss: 0.5593
# Epoch 45/200 | Train Loss: 0.5266 | Val Loss: 0.5576
# Epoch 46/200 | Train Loss: 0.5279 | Val Loss: 0.5561
# Epoch 47/200 | Train Loss: 0.5432 | Val Loss: 0.5533
# Epoch 48/200 | Train Loss: 0.5277 | Val Loss: 0.5502
# Epoch 49/200 | Train Loss: 0.5231 | Val Loss: 0.5496
# Epoch 50/200 | Train Loss: 0.5190 | Val Loss: 0.5479
# Epoch 51/200 | Train Loss: 0.5241 | Val Loss: 0.5471
# Epoch 52/200 | Train Loss: 0.5147 | Val Loss: 0.5444
# Epoch 53/200 | Train Loss: 0.5236 | Val Loss: 0.5441
# Epoch 54/200 | Train Loss: 0.5269 | Val Loss: 0.5431
# Epoch 55/200 | Train Loss: 0.5156 | Val Loss: 0.5423
# Epoch 56/200 | Train Loss: 0.5100 | Val Loss: 0.5397
# Epoch 57/200 | Train Loss: 0.5226 | Val Loss: 0.5361
# Epoch 58/200 | Train Loss: 0.5082 | Val Loss: 0.5368
# Epoch 59/200 | Train Loss: 0.5022 | Val Loss: 0.5340
# Epoch 60/200 | Train Loss: 0.5016 | Val Loss: 0.5363
# Epoch 61/200 | Train Loss: 0.4968 | Val Loss: 0.5337
# Epoch 62/200 | Train Loss: 0.5105 | Val Loss: 0.5315
# Epoch 63/200 | Train Loss: 0.5035 | Val Loss: 0.5291
# Epoch 64/200 | Train Loss: 0.5008 | Val Loss: 0.5305
# Epoch 65/200 | Train Loss: 0.4960 | Val Loss: 0.5279
# Epoch 66/200 | Train Loss: 0.4991 | Val Loss: 0.5274
# Epoch 67/200 | Train Loss: 0.4943 | Val Loss: 0.5264
# Epoch 68/200 | Train Loss: 0.4903 | Val Loss: 0.5276
# Epoch 69/200 | Train Loss: 0.5065 | Val Loss: 0.5252
# Epoch 70/200 | Train Loss: 0.4810 | Val Loss: 0.5233
# Epoch 71/200 | Train Loss: 0.4913 | Val Loss: 0.5215
# Epoch 72/200 | Train Loss: 0.4874 | Val Loss: 0.5220
# Epoch 73/200 | Train Loss: 0.4818 | Val Loss: 0.5184
# Epoch 74/200 | Train Loss: 0.4889 | Val Loss: 0.5174
# Epoch 75/200 | Train Loss: 0.4851 | Val Loss: 0.5182
# Epoch 76/200 | Train Loss: 0.4891 | Val Loss: 0.5182
# Epoch 77/200 | Train Loss: 0.4806 | Val Loss: 0.5145
# Epoch 78/200 | Train Loss: 0.4828 | Val Loss: 0.5150
# Epoch 79/200 | Train Loss: 0.4847 | Val Loss: 0.5151
# Epoch 80/200 | Train Loss: 0.4874 | Val Loss: 0.5137
# Epoch 81/200 | Train Loss: 0.4696 | Val Loss: 0.5124
# Epoch 82/200 | Train Loss: 0.4829 | Val Loss: 0.5106
# Epoch 83/200 | Train Loss: 0.4633 | Val Loss: 0.5093
# Epoch 84/200 | Train Loss: 0.4742 | Val Loss: 0.5089
# Epoch 85/200 | Train Loss: 0.4807 | Val Loss: 0.5067
# Epoch 86/200 | Train Loss: 0.4683 | Val Loss: 0.5059
# Epoch 87/200 | Train Loss: 0.4767 | Val Loss: 0.5045
# Epoch 88/200 | Train Loss: 0.4685 | Val Loss: 0.5051
# Epoch 89/200 | Train Loss: 0.4744 | Val Loss: 0.5032
# Epoch 90/200 | Train Loss: 0.4746 | Val Loss: 0.5037
# Epoch 91/200 | Train Loss: 0.4769 | Val Loss: 0.5021
# Epoch 92/200 | Train Loss: 0.4743 | Val Loss: 0.5014
# Epoch 93/200 | Train Loss: 0.4817 | Val Loss: 0.5015
# Epoch 94/200 | Train Loss: 0.4737 | Val Loss: 0.4984
# Epoch 95/200 | Train Loss: 0.4646 | Val Loss: 0.5006
# Epoch 96/200 | Train Loss: 0.4557 | Val Loss: 0.4981
# Epoch 97/200 | Train Loss: 0.4713 | Val Loss: 0.4967
# Epoch 98/200 | Train Loss: 0.4594 | Val Loss: 0.4955
# Epoch 99/200 | Train Loss: 0.4660 | Val Loss: 0.4974
# Epoch 100/200 | Train Loss: 0.4657 | Val Loss: 0.4932
# Epoch 101/200 | Train Loss: 0.4590 | Val Loss: 0.4916
# Epoch 102/200 | Train Loss: 0.4563 | Val Loss: 0.4918
# Epoch 103/200 | Train Loss: 0.4583 | Val Loss: 0.4911
# Epoch 104/200 | Train Loss: 0.4432 | Val Loss: 0.4898
# Epoch 105/200 | Train Loss: 0.4630 | Val Loss: 0.4910
# Epoch 106/200 | Train Loss: 0.4703 | Val Loss: 0.4874
# Epoch 107/200 | Train Loss: 0.4422 | Val Loss: 0.4894
# Epoch 108/200 | Train Loss: 0.4492 | Val Loss: 0.4879
# Epoch 109/200 | Train Loss: 0.4858 | Val Loss: 0.4874
# Epoch 110/200 | Train Loss: 0.4745 | Val Loss: 0.4844
# Epoch 111/200 | Train Loss: 0.4580 | Val Loss: 0.4850
# Epoch 112/200 | Train Loss: 0.4572 | Val Loss: 0.4856
# Epoch 113/200 | Train Loss: 0.4505 | Val Loss: 0.4850
# Epoch 114/200 | Train Loss: 0.4458 | Val Loss: 0.4822
# Epoch 115/200 | Train Loss: 0.4453 | Val Loss: 0.4836
# Epoch 116/200 | Train Loss: 0.4709 | Val Loss: 0.4832
# Epoch 117/200 | Train Loss: 0.4455 | Val Loss: 0.4837
# Epoch 118/200 | Train Loss: 0.4480 | Val Loss: 0.4843
# Epoch 119/200 | Train Loss: 0.4373 | Val Loss: 0.4817
# Epoch 120/200 | Train Loss: 0.4412 | Val Loss: 0.4817
# Epoch 121/200 | Train Loss: 0.4460 | Val Loss: 0.4792
# Epoch 122/200 | Train Loss: 0.4485 | Val Loss: 0.4782
# Epoch 123/200 | Train Loss: 0.4302 | Val Loss: 0.4796
# Epoch 124/200 | Train Loss: 0.4397 | Val Loss: 0.4768
# Epoch 125/200 | Train Loss: 0.4469 | Val Loss: 0.4793
# Epoch 126/200 | Train Loss: 0.4521 | Val Loss: 0.4764
# Epoch 127/200 | Train Loss: 0.4435 | Val Loss: 0.4771
# Epoch 128/200 | Train Loss: 0.4534 | Val Loss: 0.4771
# Epoch 129/200 | Train Loss: 0.4340 | Val Loss: 0.4757
# Epoch 130/200 | Train Loss: 0.4407 | Val Loss: 0.4751
# Epoch 131/200 | Train Loss: 0.4468 | Val Loss: 0.4763
# Epoch 132/200 | Train Loss: 0.4353 | Val Loss: 0.4734
# Epoch 133/200 | Train Loss: 0.4375 | Val Loss: 0.4740
# Epoch 134/200 | Train Loss: 0.4269 | Val Loss: 0.4715
# Epoch 135/200 | Train Loss: 0.4427 | Val Loss: 0.4728
# Epoch 136/200 | Train Loss: 0.4380 | Val Loss: 0.4720
# Epoch 137/200 | Train Loss: 0.4271 | Val Loss: 0.4701
# Epoch 138/200 | Train Loss: 0.4319 | Val Loss: 0.4709
# Epoch 139/200 | Train Loss: 0.4402 | Val Loss: 0.4711
# Epoch 140/200 | Train Loss: 0.4350 | Val Loss: 0.4696
# Epoch 141/200 | Train Loss: 0.4406 | Val Loss: 0.4685
# Epoch 142/200 | Train Loss: 0.4244 | Val Loss: 0.4704
# Epoch 143/200 | Train Loss: 0.4291 | Val Loss: 0.4678
# Epoch 144/200 | Train Loss: 0.4212 | Val Loss: 0.4670
# Epoch 145/200 | Train Loss: 0.4166 | Val Loss: 0.4669
# Epoch 146/200 | Train Loss: 0.4292 | Val Loss: 0.4656
# Epoch 147/200 | Train Loss: 0.4232 | Val Loss: 0.4670
# Epoch 148/200 | Train Loss: 0.4239 | Val Loss: 0.4639
# Epoch 149/200 | Train Loss: 0.4381 | Val Loss: 0.4670
# Epoch 150/200 | Train Loss: 0.4276 | Val Loss: 0.4629
# Epoch 151/200 | Train Loss: 0.4277 | Val Loss: 0.4660
# Epoch 152/200 | Train Loss: 0.4225 | Val Loss: 0.4648
# Epoch 153/200 | Train Loss: 0.4343 | Val Loss: 0.4655
# Epoch 154/200 | Train Loss: 0.4295 | Val Loss: 0.4617
# Epoch 155/200 | Train Loss: 0.4185 | Val Loss: 0.4613
# Epoch 156/200 | Train Loss: 0.4112 | Val Loss: 0.4627
# Epoch 157/200 | Train Loss: 0.4266 | Val Loss: 0.4623
# Epoch 158/200 | Train Loss: 0.4179 | Val Loss: 0.4601
# Epoch 159/200 | Train Loss: 0.4351 | Val Loss: 0.4600
# Epoch 160/200 | Train Loss: 0.4182 | Val Loss: 0.4589
# Epoch 161/200 | Train Loss: 0.4316 | Val Loss: 0.4601
# Epoch 162/200 | Train Loss: 0.4181 | Val Loss: 0.4602
# Epoch 163/200 | Train Loss: 0.4069 | Val Loss: 0.4584
# Epoch 164/200 | Train Loss: 0.4176 | Val Loss: 0.4584
# Epoch 165/200 | Train Loss: 0.4190 | Val Loss: 0.4594
# Epoch 166/200 | Train Loss: 0.4111 | Val Loss: 0.4585
# Epoch 167/200 | Train Loss: 0.4196 | Val Loss: 0.4594
# Epoch 168/200 | Train Loss: 0.4175 | Val Loss: 0.4580
# Epoch 169/200 | Train Loss: 0.4069 | Val Loss: 0.4571
# Epoch 170/200 | Train Loss: 0.4114 | Val Loss: 0.4565
# Epoch 171/200 | Train Loss: 0.4176 | Val Loss: 0.4561
# Epoch 172/200 | Train Loss: 0.4091 | Val Loss: 0.4572
# Epoch 173/200 | Train Loss: 0.4119 | Val Loss: 0.4554
# Epoch 174/200 | Train Loss: 0.4272 | Val Loss: 0.4584
# Epoch 175/200 | Train Loss: 0.4317 | Val Loss: 0.4572
# Epoch 176/200 | Train Loss: 0.3997 | Val Loss: 0.4547
# Epoch 177/200 | Train Loss: 0.4053 | Val Loss: 0.4559
# Epoch 178/200 | Train Loss: 0.4057 | Val Loss: 0.4556
# Epoch 179/200 | Train Loss: 0.4097 | Val Loss: 0.4521
# Epoch 180/200 | Train Loss: 0.3997 | Val Loss: 0.4530
# Epoch 181/200 | Train Loss: 0.4098 | Val Loss: 0.4526
# Epoch 182/200 | Train Loss: 0.4024 | Val Loss: 0.4507
# Epoch 183/200 | Train Loss: 0.4094 | Val Loss: 0.4529
# Epoch 184/200 | Train Loss: 0.4134 | Val Loss: 0.4530
# Epoch 185/200 | Train Loss: 0.3967 | Val Loss: 0.4521
# Epoch 186/200 | Train Loss: 0.4029 | Val Loss: 0.4518
# Epoch 187/200 | Train Loss: 0.3990 | Val Loss: 0.4514
# Epoch 188/200 | Train Loss: 0.4009 | Val Loss: 0.4493
# Epoch 189/200 | Train Loss: 0.4035 | Val Loss: 0.4505
# Epoch 190/200 | Train Loss: 0.4058 | Val Loss: 0.4512
# Epoch 191/200 | Train Loss: 0.3951 | Val Loss: 0.4487
# Epoch 192/200 | Train Loss: 0.3926 | Val Loss: 0.4486
# Epoch 193/200 | Train Loss: 0.4114 | Val Loss: 0.4488
# Epoch 194/200 | Train Loss: 0.4004 | Val Loss: 0.4495
# Epoch 195/200 | Train Loss: 0.4092 | Val Loss: 0.4508
# Epoch 196/200 | Train Loss: 0.4004 | Val Loss: 0.4470
# Epoch 197/200 | Train Loss: 0.4100 | Val Loss: 0.4474
# Epoch 198/200 | Train Loss: 0.4034 | Val Loss: 0.4454
# Epoch 199/200 | Train Loss: 0.4040 | Val Loss: 0.4508
# Epoch 200/200 | Train Loss: 0.4071 | Val Loss: 0.4474

# %% [markdown]
# ## Evaluation

# %%
plt.figure(figsize=(8, 4))
plt.plot(train_losses, label="Train Loss", marker='o')
plt.plot(val_losses, label="Validation Loss", marker='x')
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Reconstructing single samples
# Before we do any Clustering, let's see how good the model is in reconstructing one sample.

# %%
# X_recon_all = helper_functions.reconstruct_in_batches(X, model, device, 64)
original_z = helper_functions.preprocessing(ds, ["thetao"], [50], "location", -1)
print(original_z.shape)
importlib.reload(helper_functions)
coords = original_z.location  # z. B. aus dem preprocessing()
# reconstructed_z = helper_functions.reconstructed_to_stack(ds, "thetao", 50, X_recon_all, coords)
# print(reconstructed_z.shape)

helper_functions.plot_reconstruction_comparison(
    z_stack_original=original_z,
    z_stack_recon=original_z,# reconstructed_z,
    time_indices=[0, 15, 80, 176],
    cmin=-2,
    cmax=2
)
# Out:
# (342, 34974)

# %% [markdown]
# ## Clustering with K-Means

# %% [markdown]
# ### Clustering the reconstructions

# %% [markdown]
# ### Latent = 3

# %%
importlib.reload(helper_functions)
# Out:
# <module 'helper_functions' from '/home/jovyan/spatiotemporal-mining-medsea/notebooks/helper_functions.py'>

# %%
k=9
labels = helper_functions.apply_kmeans(X_recon_all, k)
labels += 1

helper_functions.plot_cluster_timeline(z_temp, labels)

# %% [markdown]
# ### Depth = 50

# %%
recon_temp_50 = helper_functions.reconstructed_to_stack(ds, "thetao", 50, X_recon_all)
helper_functions.plot_average_cluster(recon_temp_50, labels, -2, 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 recon_temp_50 = helper_functions.reconstructed_to_stack(ds, "thetao", 50, X_recon_all)
#       2 helper_functions.plot_average_cluster(recon_temp_50, labels, -2, 2)
#
# TypeError: reconstructed_to_stack() missing 1 required positional argument: 'coords'

# %%
recon_so_50 = helper_functions.reconstructed_to_stack(ds, "so", 50, X_recon_all)
helper_functions.plot_average_cluster(recon_so_50, labels, -2, 2)

# %% [markdown]
# ### Depth = 300

# %%
recon_temp_300 = helper_functions.reconstructed_to_stack(ds, "thetao", 300, X_recon_all)
helper_functions.plot_average_cluster(recon_temp_300, labels, -2, 2)

# %%
recon_so_300 = helper_functions.reconstructed_to_stack(ds, "so", 300, X_recon_all)
helper_functions.plot_average_cluster(recon_so_300, labels, -2, 2)

# %% [markdown]
# ### Depth = 1000

# %%
recon_temp_1000 = helper_functions.reconstructed_to_stack(ds, "thetao", 300, X_recon_all)
helper_functions.plot_average_cluster(recon_temp_50, labels, -2, 2)

# %%
recon_so_1000 = helper_functions.reconstructed_to_stack(ds, "so", 1000, X_recon_all)
helper_functions.plot_average_cluster(recon_so_1000, labels, -2, 2)

# %% [markdown]
# ### Latent clustering

# %%
# import numpy as np
# import torch
# from sklearn.cluster import KMeans

# def encode_latents(model, X, batch_size=128):
#     """
#     X: NumPy array (n_samples, n_features)
#     model: trained autoencoder
#     returns: (n_samples, latent_dim)
#     """
#     model.eval()
#     latents = []

#     with torch.no_grad():
#         for i in range(0, len(X), batch_size):
#             batch = X[i:i+batch_size]
#             batch = torch.tensor(batch, dtype=torch.float32).to(device)
#             z = model.encoder(batch)
#             latents.append(z.cpu().numpy())

#     return np.concatenate(latents, axis=0)

# # 1. Latents berechnen
# latents_train = encode_latents(model, X_train)
# latents_test = encode_latents(model, X_test)
# latents_all = np.vstack([latents_train, latents_test])
# # 2. Clustering mit KMeans
# k = 9  # z.B. 5 Cluster
# kmeans = KMeans(n_clusters=k, n_init="auto", random_state=0)
# labels = kmeans.fit_predict(latents_all)
# labels += 1


# helper_functions.plot_cluster_timeline(z_temp, labels)

# plot_cluster_average_reconstructions(
#     model=model,
#     X=np.vstack([X_train, X_test]),
#     labels=labels,
#     z_stack=z_stack,
#     num_clusters=k,
#     device=device
# )
