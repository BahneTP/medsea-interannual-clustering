# %% [markdown]
# # Autoencoder
# This notebook makes use of the **Autoencoder**, which is used to reduce the dimensionality of our dataset in a non-linear way. Furthermore, we then apply **k-means Clustering** as in our last notebook in our new created **Latent Space** in lower dimension. We do so, to get rid of less important variables and achieve a better Clustering.

# %%
# !pip install -q -r ../../requirements.txt &> /dev/null

# %%
import importlib
from ipywidgets import FloatSlider
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from ipywidgets import interact, IntSlider
from sklearn.decomposition import PCA
import numpy as np
import pandas as pd
import matplotlib.dates as mdates
import random

import torch
import torch.nn as nn
from torchinfo import summary
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from torch.utils.data import DataLoader, TensorDataset, random_split

import sys
sys.path.append('../..')
import helper_functions     # Own file.
import importlib
importlib.reload(helper_functions)

import warnings
warnings.filterwarnings("ignore", message="Degrees of freedom <= 0 for slice")

# %%
SEED = 27

np.random.seed(SEED)
torch.manual_seed(SEED)
random.seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# ## Data Loading & Preprocessing

# %%
trend_removal = True

# %%
ds_train = xr.open_dataset("../../data/medsea1987to2025_train.nc")

z_temp = helper_functions.preprocessing(ds_train, ["thetao", "so"], [50, 300, 1000], "location", trend_removal, 1)
X_train = z_temp.values.astype(np.float32)
input_dimension = X_train.shape[1]

train_loader = DataLoader(TensorDataset(torch.from_numpy(X_train)), batch_size=32, shuffle=True)

# %%
ds_train = xr.open_dataset("../../data/medsea1987to2025_val.nc")

z_temp = helper_functions.preprocessing(ds_train, ["thetao", "so"], [50, 300, 1000], "location", trend_removal, 1)
X_val = z_temp.values.astype(np.float32)
val_dataset = TensorDataset(torch.from_numpy(X_val))

val_size = int(0.4 * len(val_dataset))
_ , val_subset = random_split(
    val_dataset,
    [len(val_dataset) - val_size, val_size],
    generator=torch.Generator().manual_seed(SEED)
)

val_loader = DataLoader(val_subset, batch_size=32, shuffle=False)

# %% [markdown]
# ## The Architecture

# %%
class Autoencoder(nn.Module):
    def __init__(self, input_dim, latent_dim, dropout):
        super().__init__()

        # Encoder
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 512),
            nn.BatchNorm1d(512),
            nn.Dropout(dropout),
            nn.LeakyReLU(),

            nn.Linear(512, 32),
            nn.BatchNorm1d(32),
            nn.Dropout(dropout),
            nn.LeakyReLU(),

            nn.Linear(32, latent_dim)
        )

        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 32),
            nn.BatchNorm1d(32),
            nn.LeakyReLU(),

            nn.Linear(32, 512),
            nn.BatchNorm1d(512),
            nn.LeakyReLU(),

            nn.Linear(512, input_dim)
        )

    def forward(self, x):
        z = self.encoder(x)
        return self.decoder(z)

# %% [markdown]
# ## Training Loop

# %%
def train(num_epochs: int):
    torch.cuda.empty_cache()

    train_losses = []
    val_losses = []
    for epoch in range(num_epochs):
        model.train()
        running_train_loss = 0.0
        for batch in train_loader:
            x = batch[0].to(device).float()
                    
            optimizer.zero_grad()
            x_recon = model(x)
            loss = loss_fn(x_recon, x)
            loss.backward()
            optimizer.step()
            running_train_loss += loss.item() * x.size(0)
    
        train_loss = running_train_loss / len(train_loader.dataset)
        train_losses.append(train_loss)
    
        # Validation
        model.eval()
        running_val_loss = 0.0
        with torch.no_grad():
            for batch in val_loader:
                x = batch[0].to(device).float()
                x_recon = model(x)
                loss = loss_fn(x_recon, x)
                running_val_loss += loss.item() * x.size(0)
    
        val_loss = running_val_loss / len(val_loader.dataset)
        val_losses.append(val_loss)
        if (epoch+1) % 10 == 0:
            print(f"Epoch {epoch+1}/{num_epochs} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")
    return train_losses, val_losses

# %% [markdown]
# ## Setup

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Training using device: {device}')

model = Autoencoder(input_dim=input_dimension, latent_dim=3, dropout=0.2).to(device)
model = model.float()

summary(model, input_size=(1, input_dimension))
# Out:
# Training using device: cuda
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Autoencoder                              [1, 172224]               --
# ├─Sequential: 1-1                        [1, 3]                    --
# │    └─Linear: 2-1                       [1, 512]                  88,179,200
# │    └─BatchNorm1d: 2-2                  [1, 512]                  1,024
# │    └─Dropout: 2-3                      [1, 512]                  --
# │    └─LeakyReLU: 2-4                    [1, 512]                  --
# │    └─Linear: 2-5                       [1, 32]                   16,416
# │    └─BatchNorm1d: 2-6                  [1, 32]                   64
# │    └─Dropout: 2-7                      [1, 32]                   --
# │    └─LeakyReLU: 2-8                    [1, 32]                   --
# │    └─Linear: 2-9                       [1, 3]                    99
# ├─Sequential: 1-2                        [1, 172224]               --
# │    └─Linear: 2-10                      [1, 32]                   128
# │    └─BatchNorm1d: 2-11                 [1, 32]                   64
# │    └─LeakyReLU: 2-12                   [1, 32]                   --
# │    └─Linear: 2-13                      [1, 512]                  16,896
# │    └─BatchNorm1d: 2-14                 [1, 512]                  1,024
# │    └─LeakyReLU: 2-15                   [1, 512]                  --
# │    └─Linear: 2-16                      [1, 172224]               88,350,912
# ==========================================================================================
# Total params: 176,565,827
# Trainable params: 176,565,827
# Non-trainable params: 0
# Total mult-adds (M): 176.57
# ==========================================================================================
# Input size (MB): 0.69
# Forward/backward pass size (MB): 1.40
# Params size (MB): 706.26
# Estimated Total Size (MB): 708.35
# ==========================================================================================

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
loss_fn = nn.MSELoss()
num_epochs = 800
train_losses, val_losses = train(num_epochs)
# Out:
# Epoch 10/800 | Train Loss: 0.7183 | Val Loss: 0.6557
# Epoch 20/800 | Train Loss: 0.6612 | Val Loss: 0.5909
# Epoch 30/800 | Train Loss: 0.6232 | Val Loss: 0.5669
# Epoch 40/800 | Train Loss: 0.6105 | Val Loss: 0.5498
# Epoch 50/800 | Train Loss: 0.6143 | Val Loss: 0.5338
# Epoch 60/800 | Train Loss: 0.5930 | Val Loss: 0.5225
# Epoch 70/800 | Train Loss: 0.5776 | Val Loss: 0.5114
# Epoch 80/800 | Train Loss: 0.5716 | Val Loss: 0.5008
# Epoch 90/800 | Train Loss: 0.5703 | Val Loss: 0.4921
# Epoch 100/800 | Train Loss: 0.5519 | Val Loss: 0.4863
# Epoch 110/800 | Train Loss: 0.5602 | Val Loss: 0.4796
# Epoch 120/800 | Train Loss: 0.5512 | Val Loss: 0.4730
# Epoch 130/800 | Train Loss: 0.5495 | Val Loss: 0.4683
# Epoch 140/800 | Train Loss: 0.5467 | Val Loss: 0.4628
# Epoch 150/800 | Train Loss: 0.5460 | Val Loss: 0.4560
# Epoch 160/800 | Train Loss: 0.5297 | Val Loss: 0.4540
# Epoch 170/800 | Train Loss: 0.5261 | Val Loss: 0.4471
# Epoch 180/800 | Train Loss: 0.5276 | Val Loss: 0.4412
# Epoch 190/800 | Train Loss: 0.5195 | Val Loss: 0.4399
# Epoch 200/800 | Train Loss: 0.5183 | Val Loss: 0.4368
# Epoch 210/800 | Train Loss: 0.5076 | Val Loss: 0.4308
# Epoch 220/800 | Train Loss: 0.5193 | Val Loss: 0.4291
# Epoch 230/800 | Train Loss: 0.5024 | Val Loss: 0.4264
# Epoch 240/800 | Train Loss: 0.5025 | Val Loss: 0.4248
# Epoch 250/800 | Train Loss: 0.5138 | Val Loss: 0.4244
# Epoch 260/800 | Train Loss: 0.5059 | Val Loss: 0.4196
# Epoch 270/800 | Train Loss: 0.4965 | Val Loss: 0.4161
# Epoch 280/800 | Train Loss: 0.5126 | Val Loss: 0.4172
# Epoch 290/800 | Train Loss: 0.4941 | Val Loss: 0.4130
# Epoch 300/800 | Train Loss: 0.4927 | Val Loss: 0.4084
# Epoch 310/800 | Train Loss: 0.4919 | Val Loss: 0.4092
# Epoch 320/800 | Train Loss: 0.4898 | Val Loss: 0.4050
# Epoch 330/800 | Train Loss: 0.4907 | Val Loss: 0.4055
# Epoch 340/800 | Train Loss: 0.4906 | Val Loss: 0.4035
# Epoch 350/800 | Train Loss: 0.4868 | Val Loss: 0.3992
# Epoch 360/800 | Train Loss: 0.4926 | Val Loss: 0.3978
# Epoch 370/800 | Train Loss: 0.4816 | Val Loss: 0.3957
# Epoch 380/800 | Train Loss: 0.4683 | Val Loss: 0.3964
# Epoch 390/800 | Train Loss: 0.5034 | Val Loss: 0.3931
# Epoch 400/800 | Train Loss: 0.4951 | Val Loss: 0.3944
# Epoch 410/800 | Train Loss: 0.4852 | Val Loss: 0.3920
# Epoch 420/800 | Train Loss: 0.4853 | Val Loss: 0.3894
# Epoch 430/800 | Train Loss: 0.4861 | Val Loss: 0.3861
# Epoch 440/800 | Train Loss: 0.4885 | Val Loss: 0.3853
# Epoch 450/800 | Train Loss: 0.4752 | Val Loss: 0.3864
# Epoch 460/800 | Train Loss: 0.4754 | Val Loss: 0.3831
# Epoch 470/800 | Train Loss: 0.4923 | Val Loss: 0.3816
# Epoch 480/800 | Train Loss: 0.4773 | Val Loss: 0.3811
# Epoch 490/800 | Train Loss: 0.4768 | Val Loss: 0.3790
# Epoch 500/800 | Train Loss: 0.4764 | Val Loss: 0.3783
# Epoch 510/800 | Train Loss: 0.4831 | Val Loss: 0.3754
# Epoch 520/800 | Train Loss: 0.4823 | Val Loss: 0.3744
# Epoch 530/800 | Train Loss: 0.4539 | Val Loss: 0.3725
# Epoch 540/800 | Train Loss: 0.4661 | Val Loss: 0.3726
# Epoch 550/800 | Train Loss: 0.4632 | Val Loss: 0.3749
# Epoch 560/800 | Train Loss: 0.4761 | Val Loss: 0.3706
# Epoch 570/800 | Train Loss: 0.4642 | Val Loss: 0.3687
# Epoch 580/800 | Train Loss: 0.4693 | Val Loss: 0.3679
# Epoch 590/800 | Train Loss: 0.4507 | Val Loss: 0.3695
# Epoch 600/800 | Train Loss: 0.4651 | Val Loss: 0.3665
# Epoch 610/800 | Train Loss: 0.4718 | Val Loss: 0.3649
# Epoch 620/800 | Train Loss: 0.4487 | Val Loss: 0.3641
# Epoch 630/800 | Train Loss: 0.4701 | Val Loss: 0.3633
# Epoch 640/800 | Train Loss: 0.4557 | Val Loss: 0.3623
# Epoch 650/800 | Train Loss: 0.4671 | Val Loss: 0.3624
# Epoch 660/800 | Train Loss: 0.4476 | Val Loss: 0.3611
# Epoch 670/800 | Train Loss: 0.4637 | Val Loss: 0.3582
# Epoch 680/800 | Train Loss: 0.4505 | Val Loss: 0.3592
# Epoch 690/800 | Train Loss: 0.4519 | Val Loss: 0.3604
# Epoch 700/800 | Train Loss: 0.4620 | Val Loss: 0.3565
# Epoch 710/800 | Train Loss: 0.4474 | Val Loss: 0.3583
# Epoch 720/800 | Train Loss: 0.4519 | Val Loss: 0.3544
# Epoch 730/800 | Train Loss: 0.4507 | Val Loss: 0.3544
# Epoch 740/800 | Train Loss: 0.4528 | Val Loss: 0.3550
# Epoch 750/800 | Train Loss: 0.4641 | Val Loss: 0.3543
# Epoch 760/800 | Train Loss: 0.4507 | Val Loss: 0.3548
# Epoch 770/800 | Train Loss: 0.4402 | Val Loss: 0.3514
# Epoch 780/800 | Train Loss: 0.4462 | Val Loss: 0.3512
# Epoch 790/800 | Train Loss: 0.4521 | Val Loss: 0.3502
# Epoch 800/800 | Train Loss: 0.4487 | Val Loss: 0.3498

# %% [markdown]
# ## Evaluation

# %%
helper_functions.plot_metrics([(train_losses, "Train Loss"), (val_losses, "Validation Loss")], "Loss (MSE)")

# %%
torch.save(model.state_dict(), "AE.pth")
