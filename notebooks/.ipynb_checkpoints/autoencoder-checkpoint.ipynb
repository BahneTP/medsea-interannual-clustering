# %% [markdown]
# # Autoencoder
# This notebook makes use of the **Autoencoder**, which is used to reduce the dimensionality of our dataset in a non-linear way. Furthermore, we then apply **k-means Clustering** as in our last notebook in our new created **Latent Space** in lower dimension. We do so, to get rid of less important variables and achieve a better Clustering.

# %%
# !pip install cartopy xarray matplotlib netCDF4 torch

# %%
import helper_functions
import importlib
from ipywidgets import FloatSlider
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from ipywidgets import interact, IntSlider
from sklearn.decomposition import PCA
import numpy as np
import pandas as pd
import matplotlib.dates as mdates

import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from torch.utils.data import DataLoader, TensorDataset

# %% [markdown]
# ## Data Loading & Preprocessing

# %%
ds = xr.open_dataset("/home/jovyan/spatiotemporal-mining-medsea/data/medsea.nc")

def preprocessing(features: list, depths: list, dim):
    """
    feature: List of features to combine. "sol" for Salinity or "temperature for Temperature.
    depth: "Any value from 0 to 1062, but it will assign the closest existing."

    returns a stacked array of the "feature".
    """

    def standardize(group):
        m = group.mean("time")
        s = group.std("time")
        return (group - m) / s

    feature_vectors = []
    for feature in features:

        for depth in depths:
            data = ds[feature].sel(depth=depth, method="nearest")
            data = data.assign_coords(month=data["time"].dt.month)
        
            z = data.groupby("month").apply(standardize)
            z = z.stack(location=("latitude", "longitude"))
            # z = z.dropna(dim="location", how="any")
            feature_vectors.append(z)
    
    z_concat = xr.concat(feature_vectors, dim=dim)
    z_concat = z_concat.dropna(dim="location", how="any")

    return z_concat  # → xarray.DataArray mit dims: ("time", "location")

# %%
z_temp = preprocessing(["thetao", "so"], [50], "location")
X = z_temp.values
input_dimension = X.shape[1]
print(X.shape[1])
# Out:
# 81314

# %% [markdown]
# ## Splitting

# %%
X = X.astype(np.float32)  # <- wichtig!
X_train, X_test = train_test_split(X, test_size=0.2, random_state=27)

train_loader = DataLoader(TensorDataset(torch.from_numpy(X_train)), batch_size=16, shuffle=True)
test_loader = DataLoader(TensorDataset(torch.from_numpy(X_test)), batch_size=16, shuffle=False)

# %% [markdown]
# ## The Architecture

# %%
# 3. Autoencoder definieren
class Autoencoder(nn.Module):
    def __init__(self, input_dim, latent_dim):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 1024),
            nn.ReLU(),
            nn.Dropout(p=0.1),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Dropout(p=0.1),
            nn.Linear(512, 128),
            nn.ReLU(),
            nn.Dropout(p=0.1),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(p=0.1),
            nn.Linear(64, latent_dim),
        )
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128, 512),
            nn.ReLU(),
            nn.Linear(512, 1024),
            nn.ReLU(),
            nn.Linear(1024, input_dim),
        )

    def forward(self, x):
        z = self.encoder(x)
        return self.decoder(z)

# %% [markdown]
# ## Loss Function

# %%
model = Autoencoder(input_dim=input_dimension, latent_dim=9)
model = model.float()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Training using device: {device}')
model.to(device)

# 4. Training
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
loss_fn = nn.MSELoss()
# Out:
# Training using device: cuda

# %% [markdown]
# ## Training

# %%
torch.cuda.empty_cache()

num_epochs = 3
train_losses = []
val_losses = []

for epoch in range(num_epochs):
    model.train()
    running_train_loss = 0.0
    for batch in train_loader:
        x = batch[0].to(device).float()
                
        optimizer.zero_grad()
        x_recon = model(x)
        loss = loss_fn(x_recon, x)
        loss.backward()
        optimizer.step()
        running_train_loss += loss.item() * x.size(0)

    train_loss = running_train_loss / len(train_loader.dataset)
    train_losses.append(train_loss)

    # Validation
    model.eval()
    running_val_loss = 0.0
    with torch.no_grad():
        for batch in test_loader:
            x = batch[0].to(device).float()
            x_recon = model(x)
            loss = loss_fn(x_recon, x)
            running_val_loss += loss.item() * x.size(0)

    val_loss = running_val_loss / len(test_loader.dataset)
    val_losses.append(val_loss)

    print(f"Epoch {epoch+1}/{num_epochs} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")
# Out:
# Epoch 1/3 | Train Loss: 0.9192 | Val Loss: 0.7804
# Epoch 2/3 | Train Loss: 0.8007 | Val Loss: 0.7228
# Epoch 3/3 | Train Loss: 0.7580 | Val Loss: 0.7370

# %% [markdown]
# ## Evaluation

# %%
plt.figure(figsize=(8, 4))
plt.plot(train_losses, label="Train Loss", marker='o')
plt.plot(val_losses, label="Validation Loss", marker='x')
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")
plt.title("Training vs Validation Loss")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
importlib.reload(helper_functions)
helper_functions.plot_multiple_reconstructions(device, X_test, model, z_temp, indices=[0, 1, 2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 2
#       1 importlib.reload(helper_functions)
# ----> 2 helper_functions.plot_multiple_reconstructions(device, X_test, model, z_temp, indices=[0, 1, 2])
#
# File ~/spatiotemporal-mining-medsea/notebooks/helper_functions.py:143, in plot_multiple_reconstructions(device, X, model, z_stack, indices, title_prefix)
#     140     da = xr.DataArray(vec, coords={"location": z_stack.location}, dims=["location"])
#     141     return da.unstack("location")
# --> 143 original_map = to_map(original_vector)
#     144 reco_map = to_map(reconstructed_vector)
#     146 for ax, data, title in zip(axes[i], [original_map, reco_map], ["Original", "Reconstruction"]):
#
# File ~/spatiotemporal-mining-medsea/notebooks/helper_functions.py:141, in plot_multiple_reconstructions.<locals>.to_map(vec)
#     139 def to_map(vec):
#     140     da = xr.DataArray(vec, coords={"location": z_stack.location}, dims=["location"])
# --> 141     return da.unstack("location")
#
# File /opt/conda/lib/python3.11/site-packages/xarray/core/dataarray.py:3002, in DataArray.unstack(self, dim, fill_value, sparse)
#    2941 def unstack(
#    2942     self,
#    2943     dim: Dims = None,
#    (...)
#    2946     sparse: bool = False,
#    2947 ) -> Self:
#    2948     """
#    2949     Unstack existing dimensions corresponding to MultiIndexes into
#    2950     multiple new dimensions.
#    (...)
#    3000     DataArray.stack
#    3001     """
# -> 3002     ds = self._to_temp_dataset().unstack(dim, fill_value=fill_value, sparse=sparse)
#    3003     return self._from_temp_dataset(ds)
#
# File /opt/conda/lib/python3.11/site-packages/xarray/core/dataset.py:5500, in Dataset.unstack(self, dim, fill_value, sparse)
#    5496         result = result._unstack_full_reindex(
#    5497             d, stacked_indexes[d], fill_value, sparse
#    5498         )
#    5499     else:
# -> 5500         result = result._unstack_once(d, stacked_indexes[d], fill_value, sparse)
#    5501 return result
#
# File /opt/conda/lib/python3.11/site-packages/xarray/core/dataset.py:5320, in Dataset._unstack_once(self, dim, index_and_vars, fill_value, sparse)
#    5317 variables: dict[Hashable, Variable] = {}
#    5318 indexes = {k: v for k, v in self._indexes.items() if k != dim}
# -> 5320 new_indexes, clean_index = index.unstack()
#    5321 indexes.update(new_indexes)
#    5323 for idx in new_indexes.values():
#
# File /opt/conda/lib/python3.11/site-packages/xarray/core/indexes.py:1129, in PandasMultiIndex.unstack(self)
#    1126 clean_index = remove_unused_levels_categories(self.index)
#    1128 if not clean_index.is_unique:
# -> 1129     raise ValueError(
#    1130         "Cannot unstack MultiIndex containing duplicates. Make sure entries "
#    1131         f"are unique, e.g., by  calling ``.drop_duplicates('{self.dim}')``, "
#    1132         "before unstacking."
#    1133     )
#    1135 new_indexes: dict[Hashable, Index] = {}
#    1136 for name, lev in zip(clean_index.names, clean_index.levels, strict=True):
#
# ValueError: Cannot unstack MultiIndex containing duplicates. Make sure entries are unique, e.g., by  calling ``.drop_duplicates('location')``, before unstacking.

# %% [markdown]
# ## Clustering with K-Means

# %%
import numpy as np
import torch
from sklearn.cluster import KMeans

def encode_latents(model, X, batch_size=128):
    """
    X: NumPy array (n_samples, n_features)
    model: trained autoencoder
    returns: (n_samples, latent_dim)
    """
    model.eval()
    latents = []

    with torch.no_grad():
        for i in range(0, len(X), batch_size):
            batch = X[i:i+batch_size]
            batch = torch.tensor(batch, dtype=torch.float32).to(device)
            z = model.encoder(batch)
            latents.append(z.cpu().numpy())

    return np.concatenate(latents, axis=0)

# 1. Latents berechnen
latents_train = encode_latents(model, X_train)
latents_test = encode_latents(model, X_test)
latents_all = np.vstack([latents_train, latents_test])
print(latents_all)

# 2. Clustering mit KMeans
k = 9  # z.B. 5 Cluster
kmeans = KMeans(n_clusters=k, n_init="auto", random_state=0)
labels = kmeans.fit_predict(latents_all)
labels += 1

# labels[:len(X_train)] → train cluster labels
# labels[len(X_train):] → test cluster labels
# Out:
# [[ -4.2440166  -16.190805   -40.13924    ...  52.2093     -16.69874
#   -23.488268  ]
#  [-23.123856     5.4315767   14.841052   ... -20.20178     15.549321
#    13.391273  ]
#  [-28.221653     9.07586     18.87074    ... -34.642307    21.782885
#    16.42151   ]
#  ...
#  [  0.09248818   9.064103     1.4375355  ... -23.466        2.9636796
#     0.33897996]
#  [ 23.881783    10.415713   -16.488466   ... -19.270573   -14.415978
#   -13.485325  ]
#  [ -1.2319957    6.633882     2.694312   ... -24.452236     5.1179247
#    -1.4166327 ]]

# %%
helper_functions.plot_cluster_timeline(z_temp, labels)

# %%
"""Here we preprocess only the temperature since we want
to only cluster the temperature's z-scores in the plots."""
z_temp = preprocessing(["thetao"], [50], "location") 
helper.plot_average_cluster(z_temp, labels, -1, 1)
