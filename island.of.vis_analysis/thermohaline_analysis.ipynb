# %% [markdown]
# ## Imports

# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import numpy as np
import matplotlib.pyplot as plt

import helper_functions
import importlib
importlib.reload(helper_functions)
# Out:
# <module 'helper_functions' from 'c:\\Croatia\\island.of.vis_analysis\\helper_functions.py'>

# %%
th = xr.open_dataset("data/combined_thermohaline.nc")
years = [1998, 2001, 2004, 2007, 2010, 2013, 2016, 2019, 2022, 2024]
th = th.where(th['depth'] <= 95, drop=True)
# Out:
# C:\Users\bahne\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xarray\conventions.py:204: SerializationWarning: variable 'uo' has multiple fill values {np.float32(1e+20), np.float64(1e+20)} defined, decoding all values to NaN.
#   var = coder.decode(var, name=name)
# C:\Users\bahne\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xarray\conventions.py:204: SerializationWarning: variable 'vo' has multiple fill values {np.float32(1e+20), np.float64(1e+20)} defined, decoding all values to NaN.
#   var = coder.decode(var, name=name)
# C:\Users\bahne\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xarray\conventions.py:204: SerializationWarning: variable 'mlotst' has multiple fill values {np.float32(1e+20), np.float64(1e+20)} defined, decoding all values to NaN.
# ...

# %% [markdown]
# # Temperature

# %%
helper_functions.plot_hovmoeller(
    ds=th,
    var_name='thetao',
    title="Temperature (°C)",
    year=2012,
    contour_levels=[16,17, 18, 19, 20, 21],
    mean_space=True,
    sigma=5,
    anomaly=False,
    cmin=-1,
    cmax=-1
)

# %%
helper_functions.plot_hovmoeller_grid(
    ds=th,
    var_name='thetao',
    years=years,
    cmin = 15,
    cmax = 22,
    contour_levels=[17, 18, 19, 20, 21],
    mean_space=True,
    sigma=5.0,
    nrows=5,
    ncols=2,
    anomaly=False,
    cbartitle="Temperature (°C)",
    yearcolor="white"
)
# Out:
# c:\Croatia\island.of.vis_analysis\helper_functions.py:297: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)
# c:\Croatia\island.of.vis_analysis\helper_functions.py:297: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)

# %%
importlib.reload(helper_functions)
helper_functions.plot_anomalies(th,
                                "thetao",
                                -3,
                                3,
                                "Temperature Anomaly (°C)",
                                [75],
                                730,
                                True,
                                [("vo","Northward Velocity"), ("uo", "Eastward Velocity")])

# %% [markdown]
# # Salinity

# %%
helper_functions.plot_hovmoeller(
    ds=th,
    var_name='so',
    title="Salinity (PSU)",
    year=2020,
    contour_levels=[38.8, 38.9, 39],
    mean_space=True,
    sigma=3,
    # cmin=38.4,
    # cmax=39
)

# %%
helper_functions.plot_hovmoeller_grid(
    ds=th,
    var_name='so',
    years=years,
    cmin = 38.2,
    cmax = 39,
    contour_levels=[38.2, 38.4, 38.6, 38.7, 38.8],
    mean_space=True,
    sigma=5.0,
    nrows=5,
    ncols=2,
    anomaly=False,
    cbartitle="Salinity (PSU)",
    yearcolor="white"
)
# Out:
# c:\Croatia\island.of.vis_analysis\helper_functions.py:297: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)
# c:\Croatia\island.of.vis_analysis\helper_functions.py:297: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)

# %%
helper_functions.plot_anomalies(th, "so", -2, 2, "Salinity Anomaly (PSU)", [75], 730, True, [("vo","Northward Velocity"), ("uo", "Eastward Velocity")])

# %% [markdown]
# # Northward currents

# %%
helper_functions.plot_hovmoeller_grid(
    ds=th,
    var_name='vo',
    years=years,
    cmin = -0.2,
    cmax = 0.2,
    contour_levels=[38.2, 38.4, 38.6, 38.7, 38.8],
    mean_space=True,
    sigma=5.0,
    nrows=5,
    ncols=2,
    anomaly=False,
    cbartitle="Northward sea water velocity (m/s)",
    yearcolor="white"
)
# Out:
# c:\Croatia\island.of.vis_analysis\helper_functions.py:297: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)
# c:\Croatia\island.of.vis_analysis\helper_functions.py:297: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)

# %%
helper_functions.plot_anomalies(th, "vo", -2, 2, "Northward sea water velocity (m/s))", [75], 730, False, [("vo", "Northward Velocity")])

# %% [markdown]
# # Eastward currents

# %%
helper_functions.plot_hovmoeller_grid(
    ds=th,
    var_name='uo',
    years=years,
    cmin = -0.1,
    cmax = 0.1,
    contour_levels=[38.2, 38.4, 38.6, 38.7, 38.8],
    mean_space=True,
    sigma=5.0,
    nrows=5,
    ncols=2,
    anomaly=False,
    cbartitle = "Eastward sea water velocity (m/s)",
    yearcolor="white"
)
# Out:
# c:\Croatia\island.of.vis_analysis\helper_functions.py:297: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)
# c:\Croatia\island.of.vis_analysis\helper_functions.py:297: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)

# %%
helper_functions.plot_anomalies(th, "uo", -2, 2, "Eastward sea water velocity (m/s))", [75], 730, False, [("uo", "Eastward Velocity")])

# %% [markdown]
# # Mixed Layer Depth

# %%
mlotst = th['mlotst']
mlotst = mlotst.mean(dim=['latitude', 'longitude']).sel(depth=75, method='nearest')

helper_functions.plot_variables_overyear(mlotst, 'Mixed Layer Depth over Time', 'MLD (m)', False)
# Out:
# c:\Croatia\island.of.vis_analysis\helper_functions.py:368: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
helper_functions.plot_variables_overyear(mlotst, 'MLD Anomalies (Day-of-Year) over Time', 'MLD Anomaly (m)', True)
# Out:
# c:\Croatia\island.of.vis_analysis\helper_functions.py:368: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
helper_functions.plot_variables_overyear_selected_months_multiline(
    mlotst,
    title="",
    ylabel="MLD (m)",
    months=[5,6,7, 8, 9],
    y1= 17,
    y2 = 11
)
