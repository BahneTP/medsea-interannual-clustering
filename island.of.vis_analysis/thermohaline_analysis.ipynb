# %% [markdown]
# ## Imports

# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
import scipy.ndimage

import helper_functions
import importlib
importlib.reload(helper_functions)
# Out:
# <module 'helper_functions' from 'c:\\Croatia\\island.of.vis_analysis\\helper_functions.py'>

# %%
th = xr.open_dataset("data/thermohaline_combined.nc")

# %% [markdown]
# # Temperature

# %%
helper_functions.plot_hovmoeller(
    ds=th,
    var_name='thetao',
    title="Temperature (°C)",
    year=2012,
    contour_levels=[16,17, 18, 19, 20, 21],
    mean_space=True,
    sigma=5,
    anomaly=False,
    cmin=-1,
    cmax=-1
)

# %%
helper_functions.plot_hovmoeller_grid(
    ds=th,
    var_name='thetao',
    years=[1995, 1997, 2001, 2003, 2005, 2008, 2011, 2016, 2020, 2024],
    cmin = 15,
    cmax = 22,
    contour_levels=[17, 18, 19, 20, 21],
    mean_space=True,
    sigma=5.0,
    nrows=5,
    ncols=2,
    anomaly=False,
    cbartitle="Temperature (°C)",
    yearcolor="white"
)
# Out:
# c:\Croatia\island.of.vis_analysis\helper_functions.py:182: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)
# c:\Croatia\island.of.vis_analysis\helper_functions.py:182: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)

# %%
helper_functions.plot_anomalies(th, "thetao", -3, 3, "Temperature Anomaly (°C)")

# %% [markdown]
# # Salinity

# %%
helper_functions.plot_hovmoeller(
    ds=th,
    var_name='so',
    title="Salinity (PSU)",
    year=2020,
    contour_levels=[38.8, 38.9, 39],
    mean_space=True,
    sigma=3,
    # cmin=38.4,
    # cmax=39
)

# %%
helper_functions.plot_hovmoeller_grid(
    ds=th,
    var_name='so',
    years=[1995, 1997, 2001, 2003, 2005, 2008, 2011, 2016, 2020, 2024],
    cmin = 38.2,
    cmax = 39,
    contour_levels=[38.2, 38.4, 38.6, 38.7, 38.8],
    mean_space=True,
    sigma=5.0,
    nrows=5,
    ncols=2,
    anomaly=False,
    cbartitle="Salinity (PSU)",
    yearcolor="white"
)
# Out:
# c:\Croatia\island.of.vis_analysis\helper_functions.py:182: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)
# c:\Croatia\island.of.vis_analysis\helper_functions.py:182: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)

# %%
helper_functions.plot_anomalies(th, "so", -0.8, 0.8, "Salinity Anomaly (PSU)")

# %% [markdown]
# # Northward currents

# %%
helper_functions.plot_hovmoeller_grid(
    ds=th,
    var_name='vo',
    years=[1995, 1997, 2001, 2003, 2005, 2008, 2011, 2016, 2020, 2024],
    cmin = -0.2,
    cmax = 0.2,
    contour_levels=[38.2, 38.4, 38.6, 38.7, 38.8],
    mean_space=True,
    sigma=5.0,
    nrows=5,
    ncols=2,
    anomaly=False,
    cbartitle="Northward sea water velocity (m/s)",
    yearcolor="white"
)
# Out:
# c:\Croatia\island.of.vis_analysis\helper_functions.py:182: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)
# c:\Croatia\island.of.vis_analysis\helper_functions.py:182: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)

# %% [markdown]
# # Eastward currents

# %%
helper_functions.plot_hovmoeller_grid(
    ds=th,
    var_name='uo',
    years=[1995, 1997, 2001, 2003, 2005, 2008, 2011, 2016, 2020, 2024],
    cmin = -0.1,
    cmax = 0.1,
    contour_levels=[38.2, 38.4, 38.6, 38.7, 38.8],
    mean_space=True,
    sigma=5.0,
    nrows=5,
    ncols=2,
    anomaly=False,
    cbartitle = "Eastward sea water velocity (m/s)",
    yearcolor="white"
)
# Out:
# c:\Croatia\island.of.vis_analysis\helper_functions.py:182: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)
# c:\Croatia\island.of.vis_analysis\helper_functions.py:182: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(xticklabels)

# %% [markdown]
# # Mixed Layer Depth

# %%
mlotst = th['mlotst']
mlotst = mlotst.mean(dim=['latitude', 'longitude'])

helper_functions.plot_variables_overyear(mlotst, 'Mixed Layer Depth over Time', 'MLD (m)', False)
# Out:
# c:\Croatia\island.of.vis_analysis\helper_functions.py:248: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
helper_functions.plot_variables_overyear(mlotst, 'MLD Anomalies (Day-of-Year) over Time', 'MLD Anomaly (m)')

# %%
helper_functions.plot_variables_overyear_selected_months_multiline(
    mlotst,
    title="",
    ylabel="MLD (m)",
    months=[5,6,7, 8, 9],
    y1= 17,
    y2 = 11
)
